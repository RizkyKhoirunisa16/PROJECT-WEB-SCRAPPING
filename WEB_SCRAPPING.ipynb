# %% [markdown]
# # **WEB SCRAPPING**
#
# Tujuan  : Mengambil data dari web X menggunakan tweet-harvest
#
# Library : Pandas,
#
# Output  : Dataset yang berhasil diambil serta visualisasinya

# %% [markdown]
# **Proses Mengambil Data**

# %%
twitter_auth_token = '0457d79b0975baad0bd03015939f4ed8a5b250e5'

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease [24.6 kB]
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,683 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,726 kB]
# ...

# %%
# Crawl Data

filename = 'timnas.csv'
search_keyword = 'timnas since:2024-04-01 until:2024-05-01 lang:id'
limit = 100

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼npm warn deprecated rimraf@3.0.2: Rimraf versions prior to v4 are no longer supported
# ⠼npm warn deprecated inflight@1.0.6: This module is not supported, and leaks memory. Do not use it. Check out lru-cache if you want a good and tested way to coalesce async requests by a key value, which is much more comprehensive and powerful.
# ⠼npm warn deprecated glob@7.2.3: Glob versions prior to v9 are no longer supported
# ⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1785459093043634195  Tue Apr 30 23:59:54 +0000 2024               0
# 1    1785096463435100440  Tue Apr 30 23:58:50 +0000 2024               0
# 2    1785453856333451298  Tue Apr 30 23:58:14 +0000 2024               3
# 3    1785211524115792063  Tue Apr 30 23:58:08 +0000 2024               0
# 4    1785167825432363499  Tue Apr 30 23:57:42 +0000 2024               0
# ..                   ...                             ...             ...
# 103  1785438728846225675  Tue Apr 30 22:38:59 +0000 2024               0
# 104  1785438472595218892  Tue Apr 30 22:37:58 +0000 2024              48
# 105  1784980797251842212  Tue Apr 30 22:37:48 +0000 2024               1
# 106  1785438334875316343  Tue Apr 30 22:37:25 +0000 2024               6
# 107  1785196631954227697  Tue Apr 30 22:36:56 +0000 2024               0
#
#                                              full_text               id_str  \
# ...

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 108.

# %% [markdown]
# # **CLEANING DATA**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-05adccff-375f-4c2d-ab26-68a2a615371c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-05adccff-375f-4c2d-ab26-68a2a615371c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("timnas.csv")

#menampilkan 5 baris pertama untuk cek isi data
df.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1785459093043634195  Tue Apr 30 23:59:54 +0000 2024               0
# 1  1785096463435100440  Tue Apr 30 23:58:50 +0000 2024               0
# 2  1785453856333451298  Tue Apr 30 23:58:14 +0000 2024               3
# 3  1785211524115792063  Tue Apr 30 23:58:08 +0000 2024               0
# 4  1785167825432363499  Tue Apr 30 23:57:42 +0000 2024               0
#
#                                            full_text               id_str  \
# 0  Menilik Kans Timnas Indonesia U-23 Raih Tiket ...  1785459093043634195
# 1  @MafiaWasit Nobar timnas loh Iki iso²ne rusuh ...  1785458825879052295
# 2  @jusahourly lagi ngomongin diri sendirii untuk...  1785458671721525755
# 3  @ndorokakung Wkwkwk sempet kepikiran beberapa ...  1785458649240064176
# 4  @pakwebe @jainudinwr @MulkiArdhy @ainurohman O...  1785458536958636039
#
#   image_url in_reply_to_screen_name lang  location  quote_count  reply_count  \
# ...

# %%
#cek nama kolom yang tersedia
df.columns
# Out:
# Index(['conversation_id_str', 'created_at', 'favorite_count', 'full_text',
#        'id_str', 'image_url', 'in_reply_to_screen_name', 'lang', 'location',
#        'quote_count', 'reply_count', 'retweet_count', 'tweet_url',
#        'user_id_str', 'username'],
#       dtype='object')

# %%
df = pd.read_csv("timnas.csv", na_values=["", " ", "nan", "NaN", "None"])

# %%
print(df.columns[df.isna().all()].tolist())
# Out:
# ['location']

# %%
df = df.dropna(axis=1, how='all')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   conversation_id_str      108 non-null    int64
#  1   created_at               108 non-null    object
#  2   favorite_count           108 non-null    int64
#  3   full_text                108 non-null    object
#  4   id_str                   108 non-null    int64
#  5   image_url                10 non-null     object
#  6   in_reply_to_screen_name  60 non-null     object
#  7   lang                     108 non-null    object
#  8   quote_count              108 non-null    int64
#  9   reply_count              108 non-null    int64
#  10  retweet_count            108 non-null    int64
#  11  tweet_url                108 non-null    object
#  12  user_id_str              108 non-null    int64
#  13  username                 108 non-null    object
# ...

# %%
df['created_at'] = pd.to_datetime(df['created_at'], errors='coerce')
# Out:
# <ipython-input-88-2c0f50f715ec>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['created_at'] = pd.to_datetime(df['created_at'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   conversation_id_str      108 non-null    int64
#  1   created_at               108 non-null    datetime64[ns, UTC]
#  2   favorite_count           108 non-null    int64
#  3   full_text                108 non-null    object
#  4   id_str                   108 non-null    int64
#  5   image_url                10 non-null     object
#  6   in_reply_to_screen_name  60 non-null     object
#  7   lang                     108 non-null    object
#  8   quote_count              108 non-null    int64
#  9   reply_count              108 non-null    int64
#  10  retweet_count            108 non-null    int64
#  11  tweet_url                108 non-null    object
#  12  user_id_str              108 non-null    int64
#  13  username                 108 non-null    object
# ...

# %%
df.head()
# Out:
#    conversation_id_str                created_at  favorite_count  \
# 0  1785459093043634195 2024-04-30 23:59:54+00:00               0
# 1  1785096463435100440 2024-04-30 23:58:50+00:00               0
# 2  1785453856333451298 2024-04-30 23:58:14+00:00               3
# 3  1785211524115792063 2024-04-30 23:58:08+00:00               0
# 4  1785167825432363499 2024-04-30 23:57:42+00:00               0
#
#                                            full_text               id_str  \
# 0  Menilik Kans Timnas Indonesia U-23 Raih Tiket ...  1785459093043634195
# 1  @MafiaWasit Nobar timnas loh Iki iso²ne rusuh ...  1785458825879052295
# 2  @jusahourly lagi ngomongin diri sendirii untuk...  1785458671721525755
# 3  @ndorokakung Wkwkwk sempet kepikiran beberapa ...  1785458649240064176
# 4  @pakwebe @jainudinwr @MulkiArdhy @ainurohman O...  1785458536958636039
#
#   image_url in_reply_to_screen_name lang  quote_count  reply_count  \
# ...

# %% [markdown]
# # **VISUALISASI DATA**

# %%
# Tujuan: Melihat distribusi atau tren tweet berdasarkan waktu.

df['hour'] = df['created_at'].dt.hour
sns.countplot(data=df, x='hour')
plt.title("Distribusi Tweet Berdasarkan Jam")
plt.xlabel("Jam")
plt.ylabel("Jumlah Tweet")
plt.show()

# %%
#Tujuan: Melihat tweet mana yang paling banyak mendapat respons.

top_fav = df.nlargest(10, 'favorite_count')
plt.figure(figsize=(10, 6))
sns.barplot(data=top_fav, x='favorite_count', y='username')
plt.title("Top 10 Tweet berdasarkan Jumlah Suka")
plt.xlabel("Jumlah Suka")
plt.ylabel("Username")
plt.show()

# %%
#Tujuan: Mengetahui siapa pengguna yang paling banyak menulis tentang Timnas.

plt.figure(figsize=(10,6))
df['username'].value_counts().head(10).plot(kind='bar')
plt.title("10 Pengguna dengan Jumlah Tweet Terbanyak")
plt.xlabel("Username")
plt.ylabel("Jumlah Tweet")
plt.show()

# %%
#Tujuan: Mengetahui proporsi tweet murni dan balasan.

df['is_reply'] = df['in_reply_to_screen_name'].notna()
df['is_reply'].value_counts().plot(kind='pie', labels=['Tweet Asli', 'Balasan'], autopct='%1.1f%%')
plt.title("Proporsi Tweet Asli vs Balasan")
plt.ylabel("")
plt.show()

# %% [markdown]
# Proyek ini menunjukkan bagaimana percakapan publik mengenai Timnas (tim nasional sepak bola Indonesia) dapat dikumpulkan secara otomatis dari platform X (sebelumnya Twitter) dengan menggunakan Tweet Harvester. Data diperoleh berdasarkan kata kunci "Timnas" yang mencakup berbagai topik, seperti hasil pertandingan, dukungan suporter, serta isu yang melibatkan pemain. Analisis kata digunakan untuk mengidentifikasi kata-kata yang paling sering muncul, sementara metrik interaksi seperti jumlah retweet dan suka dimanfaatkan untuk mengukur tingkat perhatian publik. Proyek ini memiliki potensi untuk dikembangkan lebih lanjut melalui analisis sentimen, klasifikasi topik, maupun visualisasi tren percakapan dari waktu ke waktu.
